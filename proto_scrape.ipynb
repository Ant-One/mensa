# %%
import requests
import json

# %%
r_token = requests.get('https://idapps.ethz.ch/cookpit-pub-services/v1/weeklyrotas?client-id=ethz-wcms&lang=en&rs-first=0&rs-size=150&valid-after=2024-09-30&valid-before=2024-10-07&facility=11')

# %%
json_meals = json.dumps(r_token.json(), indent=2)

# %%
print(json_meals)
# Out:
# {
#   "weekly-rota-array": [
#     {
#       "weekly-rota-id": 1014,
#       "facility-id": 11,
#       "valid-from": "2024-09-30",
#       "valid-to": "2024-10-06",
#       "day-of-week-array": [
#         {
#           "day-of-week-code": 1,
#           "day-of-week-desc": "Monday",
#           "day-of-week-desc-short": "Mon",
#           "opening-hour-array": [
#             {
#               "time-from": "07:00",
#               "time-to": "17:00",
#               "meal-time-array": [
#                 {
#                   "name": "Lunch",
#                   "time-from": "11:30",
#                   "time-to": "13:30",
#                   "line-array": [
#                     {
#                       "name": "World",
#                       "meal": {
#                         "line-id": 26471,
#                         "name": "Chicken Katsu Bowl",
# ...

# %%
https://idapps.ethz.ch/cookpit-pub-services/v1/weeklyrotas?client-id=ethz-wcms&lang=en&rs-first=0&rs-size=50&valid-after=2024-09-30&valid-before=2024-10-07&facility=11
